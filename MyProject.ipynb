# %% [markdown]
# <a href="https://colab.research.google.com/github/shivajalabagari/shiva/blob/main/MyProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import statements
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.functions import lit, col, udf, when
from pyspark.sql.types import StringType
from functools import reduce
import logging
import os
import findspark

# Initialize Spark
findspark.init()
spark = (
    SparkSession
    .builder
    .appName("cg-pyspark-assignment")
    .master("local")
    .config("spark.sql.repl.eagerEval.enabled", True)
    .getOrCreate()
)

# Initialize logger
LOGGER = logging.getLogger()
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def get_data_by_brand(brand: str, logger: logging.Logger = LOGGER) -> DataFrame:
    """Fetch input data based on brand.

    Args:
        brand: allowed values are (clp, okay, spar, dats, cogo)
        logger: Logger object for logging

    Returns:
        The relevant DataFrame
    """
    logger.info(f"Loading data for brand: {brand}")

    if brand not in ['clp', 'okay', 'spar', 'dats', 'cogo']:
        logger.error(f"Invalid brand value: {brand}")
        raise ValueError("Invalid brand value. Allowed values are: clp, okay, spar, dats, cogo")

    file_path = f"/content/{brand}-places.json"

    if not os.path.exists(file_path):
        logger.error(f"File path does not exist: {file_path}")
        raise FileNotFoundError(f"File path does not exist: {file_path}")

    try:
        df = spark.read.json(file_path)
        logger.info(f"Data loaded successfully for brand: {brand}")
    except Exception as e:
        logger.error(f"Error loading data for brand: {brand}: {str(e)}")
        raise

    # Add brand column
    df = df.withColumn("brand", lit(brand))
    return df

def union_all(dfs: list) -> DataFrame:
    """Combine multiple DataFrames into a single DataFrame using unionByName."""
    return reduce(lambda df1, df2: df1.unionByName(df2), dfs)

def add_missing_columns(df: DataFrame, required_cols: list) -> DataFrame:
    """Add missing columns to DataFrame with default values."""
    for col_name in required_cols:
        if col_name not in df.columns:
            df = df.withColumn(col_name, lit(None))
    return df

def handle_dataframes(dataframes: dict, required_cols: list) -> dict:
    """Ensure all DataFrames have the required columns."""
    for name, df in dataframes.items():
        dataframes[name] = add_missing_columns(df, required_cols)
    return dataframes

def preprocess_data(df: DataFrame) -> DataFrame:
    """Process DataFrame according to the given requirements.

    Args:
        df: The input DataFrame.

    Returns:
        The processed DataFrame.
    """
    # Drop 'placeSearchOpeningHours'
    if "placeSearchOpeningHours" in df.columns:
        df = df.drop("placeSearchOpeningHours")

    # Transform 'geoCoordinates' into 'lat' and 'lon'
    if "geoCoordinates" in df.columns:
        df = df.withColumn("lat", col("geoCoordinates.latitude"))
        df = df.withColumn("lon", col("geoCoordinates.longitude"))

    # Extract 'postal_code' from 'address'
    postal_code_udf = udf(lambda address: address.split()[-1] if address else None, StringType())
    df = df.withColumn("postal_code", postal_code_udf(col("address")))

    # Create 'province' column based on 'postal_code'
    df = df.withColumn("province", when(col("postal_code").between("1000", "1299"), "Brussel")
                                    .when(col("postal_code").between("1300", "1499"), "Waals-Brabant")
                                    .when(col("postal_code").between("1500", "1999"), "Vlaams-Brabant")
                                    .when(col("postal_code").between("2000", "2999"), "Antwerpen")
                                    .when(col("postal_code").between("3000", "3499"), "Vlaams-Brabant")
                                    .when(col("postal_code").between("3500", "3999"), "Limburg")
                                    .when(col("postal_code").between("4000", "4999"), "Luik")
                                    .when(col("postal_code").between("5000", "5999"), "Namen")
                                    .when(col("postal_code").between("6000", "6599"), "Henegouwen")
                                    .when(col("postal_code").between("7000", "7999"), "Henegouwen")
                                    .when(col("postal_code").between("6600", "6999"), "Luxemburg")
                                    .when(col("postal_code").between("8000", "8999"), "West-Vlaanderen")
                                    .when(col("postal_code").between("9000", "9999"), "Oost-Vlaanderen")
                                    .otherwise("Unknown"))

    # One-hot encode 'handoverServices'
    if "handoverServices" in df.columns:
        df = df.withColumn("handoverServices", col("handoverServices").cast("string"))
        df = df.withColumn("handoverServices", when(col("handoverServices").isNull(), lit("None"))
                                        .otherwise(col("handoverServices")))

    # Handle GDPR sensitive data
    df = df.withColumn("houseNumber", lit("ANONYMIZED"))
    df = df.withColumn("streetName", lit("ANONYMIZED"))

    return df

def save_data(df: DataFrame, path: str) -> None:
    """Save DataFrame to parquet file with partitioning.

    Args:
        df: The DataFrame to save.
        path: The path where the parquet file will be saved.
    """
    df.write.partitionBy("postal_code").mode("overwrite").parquet(path)
    LOGGER.info(f"Data saved successfully to: {path}")

# Initialize variables
combined_df = None
processed_df = None

# List of DataFrames and their respective names
dataframes = {
    'clp': None,
    'okay': None,
    'spar': None,
    'dats': None,
    'cogo': None
}

# Define the required columns
required_columns = ['handoverServices']

# Fetch DataFrames
try:
    for name in dataframes.keys():
        dataframes[name] = get_data_by_brand(name)

    # Ensure all DataFrames have the required columns
    dataframes = handle_dataframes(dataframes, required_columns)

    # Combine DataFrames
    combined_df = union_all(list(dataframes.values()))

    # Preprocess Data
    processed_df = preprocess_data(combined_df)

    # Save Data
    save_data(processed_df, "/content/combined_places.parquet")

except Exception as e:
    LOGGER.error(f"Failed to process data: {str(e)}")

# Show sample data for each DataFrame if they were successfully loaded
for name, df in dataframes.items():
    if df is not None:
        df.show(5)

# Show the combined DataFrame if it was successfully created
if combined_df is not None:
    combined_df.show(5)

# Show the processed DataFrame if it was successfully processed
if processed_df is not None:
    processed_df.show(5)
# Out:
# INFO:root:Loading data for brand: clp
# INFO:root:Data loaded successfully for brand: clp
# INFO:root:Loading data for brand: okay
# INFO:root:Data loaded successfully for brand: okay
# INFO:root:Loading data for brand: spar
# INFO:root:Data loaded successfully for brand: spar
# INFO:root:Loading data for brand: dats
# INFO:root:Data loaded successfully for brand: dats
# INFO:root:Loading data for brand: cogo
# INFO:root:Data loaded successfully for brand: cogo
# ERROR:root:Failed to process data: Cannot resolve column name "sellingPartners" among (address, branchId, commercialName, ensign, geoCoordinates, isActive, moreInfoUrl, placeId, placeSearchOpeningHours, placeType, routeUrl, sourceStatus, temporaryClosures, brand, handoverServices).
# +--------------------+--------+-------------------+-----------------+--------------------+----------------+--------+--------------------+-------+-----------------------+-------------------+--------------------+---------------+------------+-----------------+-----+
# |             address|branchId|     commercialName|           ensign|      geoCoordinates|handoverServices|isActive|         moreInfoUrl|placeId|placeSearchOpeningHours|          placeType|            routeUrl|sellingPartners|sourceStatus|temporaryClosures|brand|
# +--------------------+--------+-------------------+-----------------+--------------------+----------------+--------+--------------------+-------+-----------------------+-------------------+--------------------+---------------+------------+-----------------+-----+
# |{AALST, BE, Belgi...|    4156|    AALST (COLRUYT)|{8, COLR_Colruyt}|{50.933074, 4.053...|[CSOP_ORDERABLE]|    true|https://www.colru...|    902|   [{2000, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []|  clp|
# |{AALTER, BE, Belg...|    4218|   AALTER (COLRUYT)|{8, COLR_Colruyt}|{51.0784761, 3.45...|[CSOP_ORDERABLE]|    true|https://www.colru...|    946|   [{2000, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []|  clp|
# |{AARSCHOT, BE, Be...|    4222| AARSCHOT (COLRUYT)|{8, COLR_Colruyt}|{50.9760369, 4.81...|[CSOP_ORDERABLE]|    true|https://www.colru...|    950|   [{2000, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []|  clp|
# |{ALSEMBERG, BE, B...|    4138|ALSEMBERG (COLRUYT)|{8, COLR_Colruyt}|{50.7415212, 4.33...|[CSOP_ORDERABLE]|    true|https://www.colru...|    886|   [{2000, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []|  clp|
# |{AMAY, BE, België...|    3853|     AMAY (COLRUYT)|{8, COLR_Colruyt}|{50.5599284, 5.30...|[CSOP_ORDERABLE]|    true|https://www.colru...|    783|   [{2000, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []|  clp|
# +--------------------+--------+-------------------+-----------------+--------------------+----------------+--------+--------------------+-------+-----------------------+-------------------+--------------------+---------------+------------+-----------------+-----+
# only showing top 5 rows
#
# +--------------------+--------+--------------------+--------------------+--------------------+----------------+--------+--------------------+-------+-----------------------+-------------------+--------------------+---------------+------------+-----------------+-----+
# |             address|branchId|      commercialName|              ensign|      geoCoordinates|handoverServices|isActive|         moreInfoUrl|placeId|placeSearchOpeningHours|          placeType|            routeUrl|sellingPartners|sourceStatus|temporaryClosures|brand|
# +--------------------+--------+--------------------+--------------------+--------------------+----------------+--------+--------------------+-------+-----------------------+-------------------+--------------------+---------------+------------+-----------------+-----+
# |{ALKEN, BE, Belgi...|    7065|          OKAY ALKEN|      {3, COLR_OKay}|{50.8831502, 5.29...|[CSOP_ORDERABLE]|    true|https://www.okay....|   2562|   [{1930, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []| okay|
# |{AMOUGIES, BE, Be...|    4487|       OKAY AMOUGIES|      {3, COLR_OKay}|{50.7433476, 3.50...|[CSOP_ORDERABLE]|    true|https://www.okay....|   1740|   [{1930, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []| okay|
# |{ANTWERPEN 1, BE,...|    2172|OKAY COMPACT ANTW...|{4, COLR_OKayComp...|{51.2044666, 4.40...|[CSOP_ORDERABLE]|    true|https://www.okayc...|   1912|   [{1930, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []| okay|
# |{ANTWERPEN 1, BE,...|    2173|OKAY COMPACT ANTW...|{4, COLR_OKayComp...|{51.2125504, 4.39...|[CSOP_ORDERABLE]|    true|https://www.okayc...|   1913|   [{1930, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []| okay|
# |{ANTWERPEN 1, BE,...|    7108|OKAY COMPACT ANTW...|{4, COLR_OKayComp...|{51.2190789, 4.41...|[CSOP_ORDERABLE]|    true|https://www.okayc...|   2584|   [{1930, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|      [QUALITY]|          AC|               []| okay|
# +--------------------+--------+--------------------+--------------------+--------------------+----------------+--------+--------------------+-------+-----------------------+-------------------+--------------------+---------------+------------+-----------------+-----+
# only showing top 5 rows
#
# +--------------------+--------+-----------------+--------------------+--------------------+--------+--------------------+-------+-----------------------+-------------------+--------------------+------------+-----------------+-----+----------------+
# |             address|branchId|   commercialName|              ensign|      geoCoordinates|isActive|         moreInfoUrl|placeId|placeSearchOpeningHours|          placeType|            routeUrl|sourceStatus|temporaryClosures|brand|handoverServices|
# +--------------------+--------+-----------------+--------------------+--------------------+--------+--------------------+-------+-----------------------+-------------------+--------------------+------------+-----------------+-----+----------------+
# |{AALTER, BE, Belg...|    2886|      Spar Aalter|{22, RPCG_SparCol...|{51.0793465, 3.45...|    true|https://www.sparr...|    375|   [{1900, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|          AC|               []| spar|            null|
# |{ACHEL, BE, Belgi...|    2605|Spar Hamont-Achel|{22, RPCG_SparCol...|{51.2533652, 5.47...|    true|https://www.sparr...|    183|   [{1900, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|          AC|               []| spar|            null|
# |{ALKEN, BE, Belgi...|    2589|       Spar Alken|{22, RPCG_SparCol...|{50.8979311, 5.27...|    true|https://www.sparr...|    170|   [{1900, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|          AC|               []| spar|            null|
# |{ALLEUR, BE, Belg...|    9160|      Spar Alleur|{27, RPCG_SparTra...|{50.67135164072, ...|    true|https://www.sparr...|   3861|   [{1900, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|          AC|               []| spar|            null|
# |{ANGLEUR, BE, Bel...|    9017|    SPAR ANGLEDIS|{27, RPCG_SparTra...|{50.613449976, 5....|    true|https://www.sparr...|   3506|   [{1900, 30-07-202...|{1, Winkel, Winkel}|https://maps.appl...|          AC|               []| spar|            null|
# +--------------------+--------+-----------------+--------------------+--------------------+--------+--------------------+-------+-----------------------+-------------------+--------------------+------------+-----------------+-----+----------------+
# only showing top 5 rows
#
# +--------------------+--------+--------------------+---------------+--------------------+--------+--------------------+-------+--------------------+--------------------+------------+-----------------+-----+----------------+
# |             address|branchId|      commercialName|         ensign|      geoCoordinates|isActive|         moreInfoUrl|placeId|           placeType|            routeUrl|sourceStatus|temporaryClosures|brand|handoverServices|
# +--------------------+--------+--------------------+---------------+--------------------+--------+--------------------+-------+--------------------+--------------------+------------+-----------------+-----+----------------+
# |{AALST, BE, Belgi...|    3016|       DATS 24 AALST|{12, DATS_Dats}|{50.932996, 4.054...|    true|https://customer....|   2355|{8, Tankstation, ...|https://maps.appl...|          AC|               []| dats|            null|
# |{ALSEMBERG, BE, B...|    2014|   DATS 24 ALSEMBERG|{12, DATS_Dats}|{50.741285, 4.336...|    true|https://customer....|   2283|{8, Tankstation, ...|https://maps.appl...|          AC|               []| dats|            null|
# |{AMAY, BE, België...|    3884|        DATS 24 AMAY|{12, DATS_Dats}|{50.557326, 5.305...|    true|https://customer....|   2423|{8, Tankstation, ...|https://maps.appl...|          AC|               []| dats|            null|
# |{ANDERLECHT, BE, ...|    3787|DATS 24 ANDERLECH...|{12, DATS_Dats}|{50.827856, 4.302...|    true|https://customer....|   2404|{8, Tankstation, ...|https://maps.appl...|          AC|               []| dats|            null|
# |{ANDERLUES, BE, B...|    3805|   DATS 24 ANDERLUES|{12, DATS_Dats}|{50.405769, 4.273...|    true|https://customer....|   2411|{8, Tankstation, ...|https://maps.appl...|          AC|               []| dats|            null|
# +--------------------+--------+--------------------+---------------+--------------------+--------+--------------------+-------+--------------------+--------------------+------------+-----------------+-----+----------------+
# only showing top 5 rows
#
# +--------------------+--------+-------------------+--------------------+--------------------+--------------------+--------+--------------------+-------+-----------------------+--------------------+--------------------+----------------+------------+-----------------+-----+
# |             address|branchId|     commercialName|              ensign|      geoCoordinates|    handoverServices|isActive|         moreInfoUrl|placeId|placeSearchOpeningHours|           placeType|            routeUrl| sellingPartners|sourceStatus|temporaryClosures|brand|
# +--------------------+--------+-------------------+--------------------+--------------------+--------------------+--------+--------------------+-------+-----------------------+--------------------+--------------------+----------------+------------+-----------------+-----+
# |{AALST, BE, Belgi...|    8529| AALST (BIO-PLANET)|{1, COLR_Bio-Planet}|{50.9422555, 3.99...|[COLLECTNEXTDAY, ...|    true|https://www.biopl...|   3577|   [{1930, 30-07-202...|{6, Afhaalpunt, A...|https://maps.appl...|[QUALITY, BIOBE]|          AC|               []| cogo|
# |{AALST, BE, Belgi...|    7717|    AALST (COLRUYT)|   {8, COLR_Colruyt}|{50.9329969, 4.05...|[HOMEDELNEXTDAYDR...|    true|https://www.colru...|   2861|   [{2000, 30-07-202...|{6, Afhaalpunt, A...|https://maps.appl...| [CLPBE, FDBGBE]|          AC|               []| cogo|
# |{AALTER, BE, Belg...|    7814|   AALTER (COLRUYT)|   {8, COLR_Colruyt}|{51.0780228639, 3...|[PARCELCOLLECTNEX...|    true|https://www.colru...|   2956|   [{2000, 30-07-202...|{6, Afhaalpunt, A...|https://maps.appl...| [FDBGBE, CLPBE]|          AC|               []| cogo|
# |{AARSCHOT, BE, Be...|    7809| AARSCHOT (COLRUYT)|   {8, COLR_Colruyt}|{50.9763446, 4.81...|[PARCELCOLLECTNEX...|    true|https://www.colru...|   2951|   [{2000, 30-07-202...|{6, Afhaalpunt, A...|https://maps.appl...| [CLPBE, FDBGBE]|          AC|               []| cogo|
# |{ALSEMBERG, BE, B...|    7665|ALSEMBERG (COLRUYT)|   {8, COLR_Colruyt}|{50.7406275, 4.33...|    [COLLECTNEXTDAY]|    true|https://www.colru...|   2845|   [{2000, 30-07-202...|{6, Afhaalpunt, A...|https://maps.appl...|         [CLPBE]|          AC|               []| cogo|
# +--------------------+--------+-------------------+--------------------+--------------------+--------------------+--------+--------------------+-------+-----------------------+--------------------+--------------------+----------------+------------+-----------------+-----+
# only showing top 5 rows
